# %%
#Extracting Data from API - www.rapidapi.com
#Link - https://rapidapi.com/spamakashrajtech/api/corona-virus-world-and-india-data?endpoint=apiendpoint_e53bab74-70b7-42e9-9d95-4667fdcfa876
import requests
url = "https://corona-virus-world-and-india-data.p.rapidapi.com/api_india"

headers = {
    'x-rapidapi-host': "corona-virus-world-and-india-data.p.rapidapi.com",
    'x-rapidapi-key': "7f33cd970fmshbd03c56b85a368dp1e81e6jsn886a508b82d6"
    }

response = requests.request("GET", url, headers=headers).json()

# %%
#String for Current Time and Date
from datetime import datetime
now = datetime.now()
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")

# %%
#Initializing Important Functions
def confirmed(place_name):
    for state in response['state_wise']:
        if place_name.lower()==state.lower():
            return int(response['state_wise'][state]['confirmed'])
        else:
            for city in response['state_wise'][state]['district']:
                if city.lower() == place_name.lower():
                    return int(response['state_wise'][state]['district'][city]['confirmed'])
                
                
def active(place_name):
    
    for state in response['state_wise']:
        if place_name.lower()==state.lower():
            return int(response['state_wise'][state]['active'])
        else:
            for city in response['state_wise'][state]['district']:
                if city.lower() == place_name.lower():
                    return int(response['state_wise'][state]['district'][city]['active'])

def recovered(place_name):
    
    for state in response['state_wise']:
        if place_name.lower()==state.lower():
            return int(response['state_wise'][state]['recovered'])
        else:
            for city in response['state_wise'][state]['district']:
                if city.lower() == place_name.lower():
                    return int(response['state_wise'][state]['district'][city]['recovered'])

def deaths(place_name):
    
    for state in response['state_wise']:
        if place_name.lower()==state.lower():
            return int(response['state_wise'][state]['deaths'])
            
        else:
            for city in response['state_wise'][state]['district']:
                if city.lower() == place_name.lower():
                    return int(response['state_wise'][state]['district'][city]['deceased'])
                
def last_updated(place_name):
    
    for state in response['state_wise']:
        if place_name.lower()==state.lower():
            return response['state_wise'][state]['lastupdatedtime']
        else:
            for city in response['state_wise'][state]['district']:
                if city.lower() == place_name.lower():
                    return response['state_wise'][state]['lastupdatedtime']

# %%
#Output
print("COVID-19 Tracker for INDIA") 
print("************************************************************")
                
print("*Type 'India' to know Total Data of the Country")
print("*Type 'All States' to know State Wise Data of all the States")
print("*Otherwise type any State/City to know its particular Data")
print("*Type 0 to END")
print("\n")
                
flag = 1
all_states = "All States"
while flag!=0:
    place_name = input("Input Place: ")
    print("\n")
    
    if place_name == "0":
        break
    
    elif place_name == 'India' or place_name == 'india':
        print("Total number of cases in India as on "+dt_string+":")
        print("Confirmed:",int(response['total_values']['confirmed']))   
        print("Active Cases:",int(response['total_values']['active'])) 
        print("Recovered:",int(response['total_values']['recovered']))
        print("Deaths:",int(response['total_values']['deaths']))
        print("Last Updated: "+response['total_values']['lastupdatedtime']+" ")
        print("\n")
        
    
    
    elif place_name.lower()==all_states.lower():
        print('{:50s}||    {:10s}||    {:10s}||    {:10s}||    {:10s}'.format("States","Confirmed",
                                                                             "Active","Recovered","Deaths"))
        print("*****************************************************************************************************************")
        for state in response['state_wise']:
            print('{:50s}||    {:10s}||    {:10s}||    {:10s}||    {:10s}'.format(state, response['state_wise'][state]['confirmed'],
                                                response['state_wise'][state]['active'],
                                                response['state_wise'][state]['recovered'],
                                                response['state_wise'][state]['deaths']))
        print("\n")
        
    else:    
        print("Total number of cases as on "+dt_string+", "+place_name+"")
        print("Confirmed:",confirmed(place_name))   
        print("Active Cases:",active(place_name)) 
        print("Recovered:",recovered(place_name))
        print("Deaths:",deaths(place_name))
        print("Last Updated: "+last_updated(place_name)+"")
        print("\n")
# Out:
# COVID-19 Tracker for INDIA
# ************************************************************
# *Type 'India' to know Total Data of the Country
# *Type 'All States' to know State Wise Data of all the States
# *Otherwise type any State/City to know its particular Data
# *Type 0 to END
#
#
# Input Place: India
#
#
# Total number of cases in India as on 15/07/2020 16:50:50:
# Confirmed: 939198
# Active Cases: 321282
# Recovered: 593200
# Deaths: 24327
# Last Updated: 15/07/2020 16:05:58
#
#
# Input Place: All States
#
#
# States                                            ||    Confirmed ||    Active    ||    Recovered ||    Deaths
# *****************************************************************************************************************
# Maharashtra                                       ||    267665    ||    107665    ||    149007    ||    10695
# Tamil Nadu                                        ||    147324    ||    47915     ||    97310     ||    2099
# Delhi                                             ||    115346    ||    18664     ||    93236     ||    3446
# Karnataka                                         ||    44077     ||    25836     ||    17391     ||    846
# Gujarat                                           ||    43723     ||    11098     ||    30555     ||    2070
# Uttar Pradesh                                     ||    39724     ||    13760     ||    24981     ||    983
# Telangana                                         ||    37745     ||    12530     ||    24840     ||    375
# Andhra Pradesh                                    ||    33019     ||    15144     ||    17467     ||    408
# West Bengal                                       ||    32838     ||    11927     ||    19931     ||    980
# Rajasthan                                         ||    25806     ||    6080      ||    19199     ||    527
# Haryana                                           ||    22628     ||    5226      ||    17090     ||    312
# Bihar                                             ||    20173     ||    7011      ||    13019     ||    143
# Madhya Pradesh                                    ||    19005     ||    4757      ||    13575     ||    673
# Assam                                             ||    18667     ||    6439      ||    12174     ||    51
# Odisha                                            ||    14898     ||    4933      ||    9864      ||    101
# Jammu and Kashmir                                 ||    11173     ||    4755      ||    6223      ||    195
# Kerala                                            ||    8931      ||    4454      ||    4438      ||    35
# Punjab                                            ||    8511      ||    2635      ||    5663      ||    213
# Chhattisgarh                                      ||    4379      ||    1084      ||    3275      ||    20
# Jharkhand                                         ||    4246      ||    1782      ||    2428      ||    36
# Uttarakhand                                       ||    3686      ||    736       ||    2867      ||    50
# Goa                                               ||    2753      ||    1128      ||    1607      ||    18
# Tripura                                           ||    2183      ||    629       ||    1538      ||    2
# Manipur                                           ||    1672      ||    652       ||    1020      ||    0
# Puducherry                                        ||    1596      ||    685       ||    889       ||    22
# State Unassigned                                  ||    1524      ||    1524      ||    0         ||    0
# Himachal Pradesh                                  ||    1312      ||    343       ||    946       ||    10
# Ladakh                                            ||    1128      ||    181       ||    946       ||    1
# Nagaland                                          ||    902       ||    554       ||    348       ||    0
# Chandigarh                                        ||    600       ||    144       ||    446       ||    10
# Dadra and Nagar Haveli and Daman and Diu          ||    545       ||    183       ||    354       ||    1
# Arunachal Pradesh                                 ||    462       ||    306       ||    153       ||    3
# Meghalaya                                         ||    337       ||    289       ||    46        ||    2
# Mizoram                                           ||    238       ||    79        ||    159       ||    0
# Sikkim                                            ||    211       ||    112       ||    86        ||    0
# Andaman and Nicobar Islands                       ||    171       ||    42        ||    129       ||    0
# Lakshadweep                                       ||    0         ||    0         ||    0         ||    0
#
#
# Input Place: Mumbai
#
#
# Total number of cases as on 15/07/2020 16:50:50, Mumbai
# Confirmed: 95100
# Active Cases: 22773
# Recovered: 66633
# Deaths: 5405
# Last Updated: 14/07/2020 20:12:00
#
#
# Input Place: Delhi
#
#
# Total number of cases as on 15/07/2020 16:50:50, Delhi
# Confirmed: 115346
# Active Cases: 18664
# Recovered: 93236
# Deaths: 3446
# Last Updated: 14/07/2020 20:12:04
#
#
# Input Place: Hyderabad
#
#
# Total number of cases as on 15/07/2020 16:50:50, Hyderabad
# Confirmed: 28315
# Active Cases: 27987
# Recovered: 305
# Deaths: 23
# Last Updated: 14/07/2020 22:16:59
#
#
# Input Place: Gujarat
#
#
# Total number of cases as on 15/07/2020 16:50:50, Gujarat
# Confirmed: 43723
# Active Cases: 11098
# Recovered: 30555
# Deaths: 2070
# Last Updated: 14/07/2020 20:26:59
#
#
# Input Place: Punjab
#
#
# Total number of cases as on 15/07/2020 16:50:50, Punjab
# Confirmed: 8511
# Active Cases: 2635
# Recovered: 5663
# Deaths: 213
# Last Updated: 14/07/2020 20:12:02
#
#
# Input Place: 0
